# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('datos.xlsx')
df
# Out:
#                                     NAME  X_UTM21S  Y_UTM21S
# 0                                 GASPAR    436403   6610317
# 1                                ARTIGAS    553973   6630103
# 2                                  SALTO    413674   6519253
# 3                              QUEBRACHO    416092   6476790
# 4                                GUICHON    474584   6419760
# 5                       SALSIPUEDES         551142   6406910
# 6                                 PELADO    525849   6619549
# 7                                 YACARE    502110   6653944
# 8                                  BELEN    433234   6588018
# 9                               ITACUMBU    453965   6620552
# 10                        Pepe Nuñez E-1    557993   6519804
# 11                      Pepe Núñez E -1b    557990   6519776
# 12                          Quintana E-1    556027   6529736
# 13                          Quintana E-2    555825   6531309
# ...

# %%
ax1 = df.plot.scatter(x='X_UTM21S',y='Y_UTM21S')
